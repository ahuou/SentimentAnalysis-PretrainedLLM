# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\alexh\miniconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\alexh\miniconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\alexh\miniconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\alexh\miniconda3\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\alexh\miniconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\alexh\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
def preprocess_text(text):
    text = text.lower()  
    tokens = word_tokenize(text) 
    tokens = [word for word in tokens if word not in string.punctuation]  
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# %%
from data_retriever import data1, data2
# Out:
#   Cell In[7], line 1
#     from ./data_retriever import data1, data2
#           ^
# SyntaxError: invalid syntax

# %%
print(data1.head())

# %%
nltk.download('punkt')
nltk.download('stopwords')
X_1,y_1, X_2, y_2 =[],[],[],[]
for i in range(len(data1['Text'])):
    X_1.append(preprocess_text(str(data1['Text'][i])))
    y_1.append(data1['Sentiment'][i])
for i in range(len(data2['Text'])):
    X_2.append(preprocess_text(str(data2['Text'][i])))
    y_2.append(data2['Sentiment'][i])

# %%
len(X_1),len(y_1),len(X_2),len(y_2)
print(X_1[:5], y_1[:5], X_2[:5], y_2[:5])

# %%
data1['Sentiment'].hist()

# %%
data2['Sentiment'].hist()

# %%
data1['Sentiment'].value_counts()

# %%
data2['Sentiment'].value_counts()

# %%
print(data1.head())
print(data2.head())

# %%
nums = [0 if i=='Negative' else 1 for i in data1['Sentiment']]

# %%
print(nums)

# %%
tfidf = TfidfVectorizer()
X_mod = tfidf.fit_transform(X_1)

# %%
print(X_mod)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(X_mod)
#
# NameError: name 'X_mod' is not defined

# %%
X_train,X_test,y_train,y_test = train_test_split(X_mod,nums,test_size=0.4,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 X_train,X_test,y_train,y_test = train_test_split(X_mod,nums,test_size=0.4,random_state=42)
#
# NameError: name 'X_mod' is not defined

# %%
print()

# %%
print(X_train)
# Out:
#   (0, 504)	0.4405200879367854
#   (0, 3948)	0.4405200879367854
#   (0, 6713)	0.39677395309472857
#   (0, 514)	0.28879142086475973
#   (0, 6632)	0.4074274144311328
#   (0, 1898)	0.363681279589076
#   (0, 5076)	0.19141574905392145
#   (0, 3785)	0.19013913192546514
#   (1, 7115)	0.2930820343881719
#   (1, 383)	0.3345269297953012
#   (1, 1542)	0.4180424555824088
#   (1, 5475)	0.2277269473182763
#   (1, 2303)	0.2960650756007727
#   (1, 8555)	0.18350490698273983
#   (1, 361)	0.23656757773481216
#   (1, 4406)	0.18726587202312153
#   (1, 8617)	0.19870774563040658
#   (1, 3293)	0.2518025629732404
#   (1, 557)	0.37329634479188495
#   (1, 352)	0.19234553739927568
#   (1, 5726)	0.16931824226955838
#   (1, 4522)	0.2351794182494613
#   (2, 6869)	0.314477923496396
#   (2, 5430)	0.23749448598012035
#   (2, 3810)	0.2842726085410663
#   :	:
#   (4484, 5635)	0.28912881791858047
#   (4484, 672)	0.2851593453240929
#   (4484, 3908)	0.4048763459640749
#   (4484, 1470)	0.28004925327441754
#   (4484, 3293)	0.1952415641151207
#   (4485, 3249)	0.5413068815292894
#   (4485, 2536)	0.4062241253656789
#   (4485, 2)	0.3626978549439263
#   (4485, 3005)	0.30568297781223214
#   (4485, 3486)	0.32946987042179393
#   (4485, 291)	0.37174121180353503
#   (4485, 2243)	0.2650190163100219
#   (4486, 7755)	0.33491520142554787
#   (4486, 5209)	0.39413086164161043
#   (4486, 651)	0.39413086164161043
#   (4486, 749)	0.37681139130068936
#   (4486, 5353)	0.3110111740563835
#   (4486, 7248)	0.2845688711418778
#   (4486, 6317)	0.2957757789770894
#   (4486, 5298)	0.289805837871552
#   (4486, 3706)	0.23602948995383208
#   (4486, 1811)	0.17400765216136851
#   (4487, 8293)	0.7030827925386114
#   (4487, 1385)	0.5276289701911032
#   (4487, 245)	0.4767412890144755

# %%
lr = LogisticRegression()
svm = SVC()
mnb = MultinomialNB()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
accuracy_score(lr.predict(X_test),y_test),accuracy_score(lr.predict(X_train),y_train)
# Out:
# (0.8826871657754011, 0.9073083778966132)

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
accuracy_score(svm.predict(X_test),y_test)
# Out:
# 0.8937165775401069

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
accuracy_score(dt.predict(X_test),y_test),accuracy_score(dt.predict(X_train),y_train)
# Out:
# (0.8633021390374331, 0.999554367201426)

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy_score(rf.predict(X_test),y_test),accuracy_score(rf.predict(X_train),y_train)
# Out:
# (0.8933823529411765, 0.999554367201426)

# %%
print(classification_report(rf.predict(X_train),y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       629
#            1       1.00      1.00      1.00      3859
#
#     accuracy                           1.00      4488
#    macro avg       1.00      1.00      1.00      4488
# weighted avg       1.00      1.00      1.00      4488

# %%
print(classification_report(rf.predict(X_test),y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.83      0.51       200
#            1       0.99      0.90      0.94      2792
#
#     accuracy                           0.89      2992
#    macro avg       0.68      0.87      0.73      2992
# weighted avg       0.95      0.89      0.91      2992
